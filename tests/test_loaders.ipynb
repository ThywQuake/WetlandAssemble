# %%
# !which python
# !pwd
# !cd ~/repos/WA2/
# !pwd
# Out:
# ~/repos/WA2/.venv/bin/python
# /lustre/home/2200013429
# /lustre/home/2200013429

# %%
import os

# !pwd
os.chdir("/lustre/home/2200013429/repos/WA2/")
# !pwd
# Out:
# /lustre/home/2200013429
# /lustre/home/2200013429/repos/WA2

# %%
base_path = "/lustre/home/2200013429/Wetland_Assemble/data"
os.listdir(base_path)
# Out:
# ['GLWD_v2',
#  'wetland_season',
#  'GIEMS_MC',
#  'downloaded_files_id_60.txt',
#  'WAD2M',
#  'GWD30',
#  'G2017',
#  'SWAMPS',
#  'Berkeley',
#  'NRT',
#  'TOPMODEL',
#  'LSTM',
#  'catalog_id_60.json']

# %%
from WA.loaders import get_loader
from WA.config import get_dataset_config

dataset = "berkeley_rwawc"  # Example dataset name; replace with actual dataset as needed
config = get_dataset_config(dataset)
berkeley = get_loader(dataset, config)
berkeley

# %%
berkeley_tropic = berkeley.load(bbox=None, time_range=("2018-08-01", "2018-08-31"))
berkeley_tropic
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 berkeley_tropic = berkeley.load(bbox=None, time_range=("2018-08-01", "2018-08-31"))
#       2 berkeley_tropic
#
# File ~/repos/WA2/src/WA/loaders/berkeley.py:57, in BerkeleyLoader.load(self, bbox, time_range)
#      54         dataset = selected.to_dataset(name="watermask").expand_dims(time=[timestamp])
#      55         slices.append(dataset)
# ---> 57 merged = xr.concat(slices, dim="time").sortby("time")
#      58 merged = ensure_datetime_index(merged)
#      59 return self.finalize_dataset(merged, bbox=bbox, time_range=time_range)
#
# File ~/repos/WA2/.venv/lib/python3.13/site-packages/xarray/structure/concat.py:325, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     312     return _dataarray_concat(
#     313         objs,
# ...
